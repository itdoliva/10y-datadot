# %%
import json
import os
import pandas as pd
from google.oauth2 import service_account
from googleapiclient.discovery import build

# %%
MAIN_SPREADSHEET = '1zA7EzmwMVJzWOrOHG7VlNnnBoLuQGcKD54wgBuivetY'
MAIN_RANGE = 'Respostas ao formulário 1!B1:L1000'

# %%
def get_service_client():
    # Path to your service account key file
    SERVICE_ACCOUNT_FILE = 'datadot-10-years-3c9c9647d085.json'
    
    # The scope defines the level of access required
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
    
    # Authenticate using the service account
    credentials = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES
    )
    
    # Initialize the Google Sheets API service
    service = build('sheets', 'v4', credentials=credentials)

# %%
def read_spreadsheet(service_client, spreadsheet_id, range):
    result = service.spreadsheets().values().get(spreadsheetId=SPREADSHEET_ID, range=range_name).execute()
    values = result.get('values', [])
    df = pd.DataFrame(values[1:], columns=values[0])
    return df

# %%
df.rename(columns={"product_type (selecionar apenas 1)": "product_type"}, inplace=True)

df.head()
# Out:
#      client_name                                client_industry    dt_start  \
# 0  Baboom Filmes              Comunicação; Agência publicidade;  15/01/2014
# 1    Project Hub               Comunicação, Agência publicidade  01/05/2014
# 2    Project Hub               Comunicação, Agência publicidade  01/05/2014
# 3    Project Hub               Comunicação, Agência publicidade  09/05/2014
# 4      Provokers  Institutos de Pesquisa; Pesquisa & tendências  14/05/2014
#
#                          project_name                          goal  \
# 0                                Ijen                 informacional
# 1        Youtube - Rio Content Market  informacional, institucional
# 2        Youtube - Rio Content Market  informacional, institucional
# 3              Youtube - Creator Camp    educacional, institucional
# 4  Provokers - Pesquisa para a Natura                 informacional
#
#   complexity_level                                    assignment_name  \
# ...
